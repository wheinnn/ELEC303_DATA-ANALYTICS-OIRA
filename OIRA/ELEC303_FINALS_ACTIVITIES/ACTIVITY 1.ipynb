# %% [markdown]
# <h1>OIRA, JHON WAYNE L.</h1>
# <h1>BSIT - 3A</h1>

# %%
import numpy as np

# %%
import pandas as pd

# %%
penguins_data = pd.read_csv("datasets//penguins.csv")

# %%
penguins_data
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>DESCRIPTIVE ANALYTICS</h1>

# %%
penguins_data.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguins_data.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0
# year               2009.0  2009.0

# %%
penguins_data.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins_data['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339        Dream
# 340        Dream
# 341        Dream
# 342        Dream
# 343        Dream
# Name: island, Length: 344, dtype: object

# %%
penguins_data[penguins_data['island']=='Torgersen']
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
penguins_data['sex'].value_counts()
# Out:
# sex
# male      168
# female    165
# Name: count, dtype: int64

# %%
chinstrap_dataframe = penguins_data[penguins_data['species']=="Chinstrap"]

# %%
chinstrap_dataframe
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
penguins_data[(penguins_data['species'] == 'Chinstrap') & (penguins_data['body_mass_g'] >= 3000)]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
penguins_data[(penguins_data['species'] == 'Chinstrap') & (penguins_data['body_mass_g'] >= 3000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 276 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            66 non-null     object
#  1   island             66 non-null     object
#  2   bill_length_mm     66 non-null     float64
#  3   bill_depth_mm      66 non-null     float64
#  4   flipper_length_mm  66 non-null     float64
#  5   body_mass_g        66 non-null     float64
#  6   sex                66 non-null     object
#  7   year               66 non-null     int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 4.6+ KB

# %%
penguins_data['bill_length_mm'].fillna(penguins_data['bill_length_mm'].mean())
# Out:
# 0      39.10000
# 1      39.50000
# 2      40.30000
# 3      43.92193
# 4      36.70000
#          ...
# 339    55.80000
# 340    43.50000
# 341    49.60000
# 342    50.80000
# 343    50.20000
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins_data['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins_data['sex'] = penguins_data['sex'].fillna(penguins_data['sex'].mode()[0])

# %%
penguins_data.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       2
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# dtype: int64

# %%
penguins_data['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %% [markdown]
# <h1>CHANGING THE DATA TYPE OF A COLUMN</h1>

# %%
penguins_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
penguins_data['year'] = penguins_data['year'].astype('category')

# %%
penguins_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    category
# dtypes: category(1), float64(4), object(3)
# memory usage: 19.4+ KB

# %% [markdown]
# penguins_data['mass_kg'] = np.round(penguins_data['body_mass_g']/100,1)

# %%
penguins_data
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>ACTIVITY #1</h1>

# %% [markdown]
# <h3>1. In what year has the most penguins ever recorded?</h3>

# %%
penguins_data['year'].mode()
# Out:
# 0    2009
# Name: year, dtype: category
# Categories (3, int64): [2007, 2008, 2009]

# %% [markdown]
# <h3>INSIGHT: Based on the the data, the most entries or observations about penguins were recorded in the year 2009.</h3>

# %% [markdown]
# <h3>2. What is the average body mass of a Chinstrap Penguin?</h3>

# %%
chinstrap_penguins = penguins_data[penguins_data['species'] == 'Chinstrap']

# %%
chinstrap_penguins['body_mass_g'].mean
# Out:
# <bound method Series.mean of 276    3500.0
# 277    3900.0
# 278    3650.0
# 279    3525.0
# 280    3725.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 68, dtype: float64>

# %% [markdown]
# <h3>INSIGHT: The average body mass of a Chinstrap Penguin, according to the displayed dataset calculation, is 3500.0 grams.</h3>

# %% [markdown]
# <h3>3. What is the smallest record of body mass of an Adelie Penguins?</h3>

# %%
penguins_data['body_mass_g'].min()
# Out:
# np.float64(2700.0)

# %% [markdown]
# <h3>INSIGHT: The smallest recorded body mass in the entire dataset is 2,700.0 grams.</h3>

# %% [markdown]
# <h3>4. What is the highest record of flipper lenght of a Chinstrap Penguin?</h3>

# %%
penguins_data['flipper_length_mm'].max()
# Out:
# np.float64(231.0)

# %% [markdown]
# <h3>INSIGHTS: The highest recorded flipper length in the dataset is 231 millimeters.</h3>

# %% [markdown]
# <h3>5. What is the total population of the male and female in Torgersen Island?</h3>

# %%
penguins_data['sex'].value_counts()
# Out:
# sex
# male      179
# female    165
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT: The dataframe basically shows that there are 179 Male and 165 for Female.</h3>

# %% [markdown]
# <h1>DATA AGGREGATIONS:</h1>

# %% [markdown]
# <h1>ACTIVITY #2</h1>

# %% [markdown]
# <h3>1. What is the mean body mass for each year on the island of Dream?</h3>

# %%
penguins_data['body_mass_g'].mean
# Out:
# <bound method Series.mean of 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64>

# %% [markdown]
# <h3>INSIGHT: Penguins on Dream Island generally have a moderate average body mass, showing consistent weights across the recorded years with only minor variations.</h3>

# %% [markdown]
# <h3>2. How many penguins in every species are being recorded on each island?</h3>

# %%
penguins_data.groupby(['island', 'species'])['species'].count()
# Out:
# island     species
# Biscoe     Adelie        44
#            Gentoo       124
# Dream      Adelie        56
#            Chinstrap     68
# Torgersen  Adelie        52
# Name: species, dtype: int64

# %% [markdown]
# <h3>INSIGHT: Each island hosts multiple penguin species, but the population counts vary. Biscoe and Torgersen have more evenly distributed species. Dream Island has a strong representation of Adelie penguins.</h3>

# %% [markdown]
# <h3>3. Correlation of flipper lenght of penguins with their body mass.</h3>

# %%
penguins_data['flipper_length_mm'].corr(penguins_data['body_mass_g'])
# Out:
# np.float64(0.8712017673060113)

# %% [markdown]
# <h3>INSIGHT: There is a strong positive correlation between flipper length and body mass. This means penguins with longer flippers tend to be heavier.</h3>

# %% [markdown]
# <h3>4. Average of the Flipper length foe each island.</h3>

# %%
penguins_data.groupby('island')['flipper_length_mm'].mean()
# Out:
# island
# Biscoe       209.706587
# Dream        193.072581
# Torgersen    191.196078
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h3>INSIGHT: Penguins from Biscoe have the longest average flipper length. Dream and Torgersen show slightly shorter average flipper lengths. This suggests that penguin body structure may differ depending on the island environment.</h3>

# %% [markdown]
# <h3>NUMERICAL-CATEGORICAL CORRELATION TEST</h3>

# %%
from scipy.stats import f_oneway

# %% [markdown]
# <h3>5. Does the penguins in every island has the same flipper length?</h3>

# %% [markdown]
# <h3>MEAN OF BISCOE</h3>

# %%
biscoe_i = penguins[penguins['island']=='Biscoe']
flipper_biscoe = biscoe_i['flipper_length_mm'].mean()
flipper_biscoe

# %% [markdown]
# <H3>MEAN OF DREAM</H3>

# %%
dream_i = penguins[penguins['island']=='Dream']
flipper_dream = dream_i['flipper_length_mm'].mean()
flipper_dream

# %% [markdown]
# <h3>MEAN OF TORGERSEN</h3>

# %%
torgersen_i = penguins[penguins['island']=='Torgersen']
flipper_torgersen = torgersen_i['flipper_length_mm'].mean()
flipper_torgersen

# %% [markdown]
# <h3>INSIGHT: After comparing the mean flipper lengths of Biscoe, Dream, and Torgersen, the values show clear differences. This implies that penguins on each island do not have the same flipper length. The island location appears to influence penguin physical characteristics.</h3>
